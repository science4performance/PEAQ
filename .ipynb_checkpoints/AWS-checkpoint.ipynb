# %% [markdown]
# # Reading PEAQ Data from AWS
# ## This relies on AWS credentials being stored in .streamlit/secrets.toml

# %%
import streamlit as st
#import yagmail
import json
from pathlib import Path
import pandas as pd
from glob import glob
import warnings

# %% [markdown]
# ## Set up a connection to AWS s3

# %%
# This relies on AWS credentials being stored in .streamlit/secrets.toml or Streamlit Community Cloud app secrets

from st_files_connection import FilesConnection

# Create connection object 
conn = st.connection('s3', type=FilesConnection)
# Out:
# 2025-04-15 11:48:43.620 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 11:48:43.752
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/Gavin/miniconda3/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-04-15 11:48:43.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 11:48:43.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 11:48:44.254 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 11:48:44.255 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 11:48:44.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-15 11:48:44.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Load PEAQ_DB and pull in any new json files from AWS s3 peaq-streamlit/data
# - PEAQ_DB and analysis are all local

# %%
# Load PEAQ database
PEAQ_DB = pd.read_pickle('PEAQ_DB.pkl')
print(f"PEAQ_DB contains {len(PEAQ_DB)} records")
# Out:
# PEAQ_DB contains 26 records

# %%
PEAQ_DB_copy = PEAQ_DB.copy()

# %%
######Pull in all json files from s3 bucket#####
conn.fs.get("peaq-streamlit/data/*.json","./data")
#conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 ######Pull in all json files from s3 bucket#####
#       2 conn.fs.get("peaq-streamlit/data/*.json","./data")
# ----> 3 conn.close()
#
# File ~/miniconda3/lib/python3.10/site-packages/streamlit/connections/base_connection.py:86, in BaseConnection.__getattribute__(self, name)
#      82 if hasattr(self._instance, name):
#      83     raise AttributeError(
#      84         f"`{name}` doesn't exist here, but you can call `._instance.{name}` instead"
#      85     )
# ---> 86 raise e
#
# File ~/miniconda3/lib/python3.10/site-packages/streamlit/connections/base_connection.py:80, in BaseConnection.__getattribute__(self, name)
#      78 def __getattribute__(self, name: str) -> Any:
#      79     try:
# ---> 80         return object.__getattribute__(self, name)
#      81     except AttributeError as e:
#      82         if hasattr(self._instance, name):
#
# AttributeError: 'FilesConnection' object has no attribute 'close'

# %%
def load_json(file):
    """Load a file and split it into summary and answers"""
    with open(file,'r') as f:
        j = json.load(f)
    #answers = j.pop('answers')
    answers = j['answers']
    info = {answers[q]['text']:answers[q]['answer'] for q in answers if answers[q]['category']=='info'}
    scores = j.pop('scores')
    j.update(scores)
    j.update(info)
    return pd.DataFrame.from_dict( {k:[v] for k,v in j.items()}).set_index('id')

# %%
files = glob('./data/*')
print(f"{len(files)} local files")
for file in files:
    record_id = file.split('/')[-1].split('.')[0]
    if record_id not in PEAQ_DB.index:
        PEAQ_DB = pd.concat([PEAQ_DB,load_json(file)])
PEAQ_DB.to_pickle('PEAQ_DB.pkl')
# Out:
# 74 local files

# %%
items = ['count','mean','min','max']
PEAQ_DB[['sex','Please enter your age','overall_score','physical','physiological','psychological']].groupby('sex').describe().loc[:,(slice(None),items)]
# Out:
#        Please enter your age                        overall_score            \
#                        count       mean   min   max         count      mean
# sex
# Female                  54.0  41.444444  16.0  66.0          54.0  2.722222
# Male                    16.0  40.250000  18.0  73.0          16.0  2.625000
#
#                    physical                     physiological                 \
#          min   max    count      mean  min  max         count      mean  min
# sex
# Female -13.0  13.0     54.0 -1.555556 -9.0  2.0          54.0  0.481481 -4.0
# Male   -20.0  10.0     16.0 -1.187500 -8.0  2.0          16.0 -0.250000 -7.0
#
#             psychological
#         max         count      mean  min  max
# sex
# Female  7.0          54.0  3.796296 -1.0  8.0
# Male    4.0          16.0  4.062500 -5.0  8.0

# %%
PEAQ_DB[['sex','What is your main exercise type?']].groupby('sex').value_counts()
# Out:
# sex     What is your main exercise type?
# Female  Running                             34
#         Dance                                6
#         Cycling                              4
#         Swimming                             4
#         Triathlon                            3
#         Climbing                             1
#         Football                             1
#         Tennis                               1
# Male    Cycling                              9
#         Running                              3
#         Football                             2
#         Rowing                               1
#         Triathlon                            1
# Name: count, dtype: int64

# %% [markdown]
# ## Old manual method of downloading files one at a time

# %%
# Long format
files = conn.fs.ls("peaq-streamlit/data","-l")
# With time
#files = conn.fs.ls("peaq-streamlit/data","-t")
files
# Out:
# [{'Key': 'peaq-streamlit/data/15bf7e71-4c8b-4220-812b-744690554c33.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 22, 23, 54, tzinfo=tzutc()),
#   'ETag': '"11cbd632402b2690561c5e3c788f5b53"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6393,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6393,
#   'name': 'peaq-streamlit/data/15bf7e71-4c8b-4220-812b-744690554c33.json'},
#  {'Key': 'peaq-streamlit/data/2f525303-a3a9-4ac0-9729-c5a8752ca8ef.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 15, 41, 46, tzinfo=tzutc()),
#   'ETag': '"62962839ffe4a22c318f9d2e1962df27"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6418,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6418,
#   'name': 'peaq-streamlit/data/2f525303-a3a9-4ac0-9729-c5a8752ca8ef.json'},
#  {'Key': 'peaq-streamlit/data/32b2aa12-d6c2-40f5-99fd-97dd33cb797d.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 19, 52, 54, tzinfo=tzutc()),
#   'ETag': '"1dccad3fba38c2dd93b54bef878c40a7"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6465,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6465,
#   'name': 'peaq-streamlit/data/32b2aa12-d6c2-40f5-99fd-97dd33cb797d.json'},
#  {'Key': 'peaq-streamlit/data/3e1a4847-f979-4df0-ab01-f796dacb9140.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 20, 13, 49, tzinfo=tzutc()),
#   'ETag': '"4a9ced47f57717944035dca8ef7fa0e9"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6481,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6481,
#   'name': 'peaq-streamlit/data/3e1a4847-f979-4df0-ab01-f796dacb9140.json'},
#  {'Key': 'peaq-streamlit/data/464139db-cad9-4676-85ea-db7be69135e4.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 14, 50, 42, tzinfo=tzutc()),
#   'ETag': '"e64d9335a3ac7f0b22f7598a4d098d1e"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5859,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5859,
#   'name': 'peaq-streamlit/data/464139db-cad9-4676-85ea-db7be69135e4.json'},
#  {'Key': 'peaq-streamlit/data/4f1a7b38-ab65-4806-a832-d180275e06d3.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 17, 59, 27, tzinfo=tzutc()),
#   'ETag': '"248fa7be8f1eb5f28975d9d0b951fa45"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5957,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5957,
#   'name': 'peaq-streamlit/data/4f1a7b38-ab65-4806-a832-d180275e06d3.json'},
#  {'Key': 'peaq-streamlit/data/52924e12-deb1-476c-8831-687af158811f.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 17, 19, 43, tzinfo=tzutc()),
#   'ETag': '"fd9327b6e0b3169afa36ec9de84cc280"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6408,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6408,
#   'name': 'peaq-streamlit/data/52924e12-deb1-476c-8831-687af158811f.json'},
#  {'Key': 'peaq-streamlit/data/549ba9bb-e21e-44c9-ac92-6fa1af2fdfff.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 13, 15, 56, tzinfo=tzutc()),
#   'ETag': '"25c35c2e1612febedae69ffe56d0fc44"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5902,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5902,
#   'name': 'peaq-streamlit/data/549ba9bb-e21e-44c9-ac92-6fa1af2fdfff.json'},
#  {'Key': 'peaq-streamlit/data/5cc4302e-0a4c-4710-995b-b3c6c648b590.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 20, 41, 22, tzinfo=tzutc()),
#   'ETag': '"87917406e3f278c02229b15eaff22d9b"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6470,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6470,
#   'name': 'peaq-streamlit/data/5cc4302e-0a4c-4710-995b-b3c6c648b590.json'},
#  {'Key': 'peaq-streamlit/data/6ca6a81d-9fa7-48b9-9f64-9a782c3fe020.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 14, 41, 44, tzinfo=tzutc()),
#   'ETag': '"ac9916a81d72125e6397177a22a8c0f1"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6386,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6386,
#   'name': 'peaq-streamlit/data/6ca6a81d-9fa7-48b9-9f64-9a782c3fe020.json'},
#  {'Key': 'peaq-streamlit/data/759df116-d5a3-4aec-b9e0-725891cef1d7.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 13, 32, 38, tzinfo=tzutc()),
#   'ETag': '"a5be33f3df9b0b4ee27525c9e8d005c5"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6425,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6425,
#   'name': 'peaq-streamlit/data/759df116-d5a3-4aec-b9e0-725891cef1d7.json'},
#  {'Key': 'peaq-streamlit/data/7765f4a3-076d-4546-95d1-405ffa3a1b83.json',
#   'LastModified': datetime.datetime(2025, 4, 13, 1, 56, 9, tzinfo=tzutc()),
#   'ETag': '"6498404f6a3f0b549db0c47fbe41a3ec"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6558,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6558,
#   'name': 'peaq-streamlit/data/7765f4a3-076d-4546-95d1-405ffa3a1b83.json'},
#  {'Key': 'peaq-streamlit/data/781ed8fb-34ef-4b9a-932a-7b8836870e39.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 14, 25, 31, tzinfo=tzutc()),
#   'ETag': '"076255fd742af45b351c00bab77de3bd"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6450,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6450,
#   'name': 'peaq-streamlit/data/781ed8fb-34ef-4b9a-932a-7b8836870e39.json'},
#  {'Key': 'peaq-streamlit/data/8b4eb887-fc8d-4967-bb47-25486c5cd3bf.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 15, 53, 57, tzinfo=tzutc()),
#   'ETag': '"674238ab356c3bf1a90927d23931f144"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6469,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6469,
#   'name': 'peaq-streamlit/data/8b4eb887-fc8d-4967-bb47-25486c5cd3bf.json'},
#  {'Key': 'peaq-streamlit/data/8ca42ddd-cd9f-4117-94f2-9d9cc3735664.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 14, 34, 29, tzinfo=tzutc()),
#   'ETag': '"f41860f60901302e19b73dcb6d6c5ff8"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5903,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5903,
#   'name': 'peaq-streamlit/data/8ca42ddd-cd9f-4117-94f2-9d9cc3735664.json'},
#  {'Key': 'peaq-streamlit/data/92b1aac7-184f-4830-8b71-d19d522d12a7.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 15, 12, 28, tzinfo=tzutc()),
#   'ETag': '"ef41195f1ab1236182ec27f392a497af"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6442,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6442,
#   'name': 'peaq-streamlit/data/92b1aac7-184f-4830-8b71-d19d522d12a7.json'},
#  {'Key': 'peaq-streamlit/data/ab0b49e7-880c-4cbf-aca5-980ea142d302.json',
#   'LastModified': datetime.datetime(2025, 4, 13, 14, 42, 50, tzinfo=tzutc()),
#   'ETag': '"17963f9be168135d0d3990edc450789e"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6443,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6443,
#   'name': 'peaq-streamlit/data/ab0b49e7-880c-4cbf-aca5-980ea142d302.json'},
#  {'Key': 'peaq-streamlit/data/ac2ce6ce-7f4c-437b-9e0f-4310ab25334c.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 15, 3, 3, tzinfo=tzutc()),
#   'ETag': '"5b754a7fbf7bee010643219fa0c3d7b6"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5805,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5805,
#   'name': 'peaq-streamlit/data/ac2ce6ce-7f4c-437b-9e0f-4310ab25334c.json'},
#  {'Key': 'peaq-streamlit/data/ac4b44e9-8e8a-495a-b460-048179321d06.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 22, 53, 35, tzinfo=tzutc()),
#   'ETag': '"7762172a5b36fd9648349aa9ea411b63"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5868,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5868,
#   'name': 'peaq-streamlit/data/ac4b44e9-8e8a-495a-b460-048179321d06.json'},
#  {'Key': 'peaq-streamlit/data/b22079ac-e5db-4792-8843-4f3474e0fd47.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 21, 37, 14, tzinfo=tzutc()),
#   'ETag': '"443690c8ac0502b92bd0f94fe1d62033"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6527,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6527,
#   'name': 'peaq-streamlit/data/b22079ac-e5db-4792-8843-4f3474e0fd47.json'},
#  {'Key': 'peaq-streamlit/data/ba3da40b-5c52-46bd-8209-8ab0e448bba1.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 13, 30, 29, tzinfo=tzutc()),
#   'ETag': '"7225c919f47052d190326d005f5d4fe1"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5859,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5859,
#   'name': 'peaq-streamlit/data/ba3da40b-5c52-46bd-8209-8ab0e448bba1.json'},
#  {'Key': 'peaq-streamlit/data/d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 16, 46, 37, tzinfo=tzutc()),
#   'ETag': '"d55bda4ec3a0b677e8ab9201eb65d459"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 5871,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 5871,
#   'name': 'peaq-streamlit/data/d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9.json'},
#  {'Key': 'peaq-streamlit/data/d81d2ae9-cb08-4ffa-b9c8-427390de2edd.json',
#   'LastModified': datetime.datetime(2025, 4, 13, 2, 28, 16, tzinfo=tzutc()),
#   'ETag': '"e8c96fad8f8549bda8be8297a6300ff9"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6452,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6452,
#   'name': 'peaq-streamlit/data/d81d2ae9-cb08-4ffa-b9c8-427390de2edd.json'},
#  {'Key': 'peaq-streamlit/data/e2997770-5590-473d-8f2d-baa490d1b184.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 15, 36, 29, tzinfo=tzutc()),
#   'ETag': '"0b83597b7d73723d0f06320b9c31739b"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6474,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6474,
#   'name': 'peaq-streamlit/data/e2997770-5590-473d-8f2d-baa490d1b184.json'},
#  {'Key': 'peaq-streamlit/data/ec79af03-c27c-4359-8e0d-87d168043423.json',
#   'LastModified': datetime.datetime(2025, 4, 12, 17, 24, 26, tzinfo=tzutc()),
#   'ETag': '"2bbc19f7246d088532c7d31b6d872943"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6434,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6434,
#   'name': 'peaq-streamlit/data/ec79af03-c27c-4359-8e0d-87d168043423.json'},
#  {'Key': 'peaq-streamlit/data/f5350de8-3e58-48d2-ba74-b54d3f08092d.json',
#   'LastModified': datetime.datetime(2025, 4, 13, 12, 38, 39, tzinfo=tzutc()),
#   'ETag': '"ce0dd8e730ae5629eee59343be07ec65"',
#   'ChecksumAlgorithm': ['CRC32'],
#   'ChecksumType': 'FULL_OBJECT',
#   'Size': 6418,
#   'StorageClass': 'STANDARD',
#   'type': 'file',
#   'size': 6418,
#   'name': 'peaq-streamlit/data/f5350de8-3e58-48d2-ba74-b54d3f08092d.json'}]

# %%
dfl = pd.DataFrame.from_dict(files)
dfl = dfl.sort_values('LastModified', ascending=False).reset_index()
dfl['Assessment'] = dfl['name'].apply(lambda x: x.split('/')[-1].split('.')[0])

dfl[['Assessment','LastModified','Key']].set_index('Assessment')
# Out:
#                                                   LastModified  \
# Assessment
# ab0b49e7-880c-4cbf-aca5-980ea142d302 2025-04-13 14:42:50+00:00
# f5350de8-3e58-48d2-ba74-b54d3f08092d 2025-04-13 12:38:39+00:00
# d81d2ae9-cb08-4ffa-b9c8-427390de2edd 2025-04-13 02:28:16+00:00
# 7765f4a3-076d-4546-95d1-405ffa3a1b83 2025-04-13 01:56:09+00:00
# ac4b44e9-8e8a-495a-b460-048179321d06 2025-04-12 22:53:35+00:00
# 15bf7e71-4c8b-4220-812b-744690554c33 2025-04-12 22:23:54+00:00
# b22079ac-e5db-4792-8843-4f3474e0fd47 2025-04-12 21:37:14+00:00
# 5cc4302e-0a4c-4710-995b-b3c6c648b590 2025-04-12 20:41:22+00:00
# 3e1a4847-f979-4df0-ab01-f796dacb9140 2025-04-12 20:13:49+00:00
# 32b2aa12-d6c2-40f5-99fd-97dd33cb797d 2025-04-12 19:52:54+00:00
# 4f1a7b38-ab65-4806-a832-d180275e06d3 2025-04-12 17:59:27+00:00
# ec79af03-c27c-4359-8e0d-87d168043423 2025-04-12 17:24:26+00:00
# 52924e12-deb1-476c-8831-687af158811f 2025-04-12 17:19:43+00:00
# d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9 2025-04-12 16:46:37+00:00
# 8b4eb887-fc8d-4967-bb47-25486c5cd3bf 2025-04-12 15:53:57+00:00
# 2f525303-a3a9-4ac0-9729-c5a8752ca8ef 2025-04-12 15:41:46+00:00
# e2997770-5590-473d-8f2d-baa490d1b184 2025-04-12 15:36:29+00:00
# 92b1aac7-184f-4830-8b71-d19d522d12a7 2025-04-12 15:12:28+00:00
# ac2ce6ce-7f4c-437b-9e0f-4310ab25334c 2025-04-12 15:03:03+00:00
# 464139db-cad9-4676-85ea-db7be69135e4 2025-04-12 14:50:42+00:00
# 6ca6a81d-9fa7-48b9-9f64-9a782c3fe020 2025-04-12 14:41:44+00:00
# 8ca42ddd-cd9f-4117-94f2-9d9cc3735664 2025-04-12 14:34:29+00:00
# 781ed8fb-34ef-4b9a-932a-7b8836870e39 2025-04-12 14:25:31+00:00
# 759df116-d5a3-4aec-b9e0-725891cef1d7 2025-04-12 13:32:38+00:00
# ba3da40b-5c52-46bd-8209-8ab0e448bba1 2025-04-12 13:30:29+00:00
# 549ba9bb-e21e-44c9-ac92-6fa1af2fdfff 2025-04-12 13:15:56+00:00
#
#                                                                                     Key
# Assessment
# ab0b49e7-880c-4cbf-aca5-980ea142d302  peaq-streamlit/data/ab0b49e7-880c-4cbf-aca5-98...
# f5350de8-3e58-48d2-ba74-b54d3f08092d  peaq-streamlit/data/f5350de8-3e58-48d2-ba74-b5...
# d81d2ae9-cb08-4ffa-b9c8-427390de2edd  peaq-streamlit/data/d81d2ae9-cb08-4ffa-b9c8-42...
# 7765f4a3-076d-4546-95d1-405ffa3a1b83  peaq-streamlit/data/7765f4a3-076d-4546-95d1-40...
# ac4b44e9-8e8a-495a-b460-048179321d06  peaq-streamlit/data/ac4b44e9-8e8a-495a-b460-04...
# 15bf7e71-4c8b-4220-812b-744690554c33  peaq-streamlit/data/15bf7e71-4c8b-4220-812b-74...
# b22079ac-e5db-4792-8843-4f3474e0fd47  peaq-streamlit/data/b22079ac-e5db-4792-8843-4f...
# 5cc4302e-0a4c-4710-995b-b3c6c648b590  peaq-streamlit/data/5cc4302e-0a4c-4710-995b-b3...
# 3e1a4847-f979-4df0-ab01-f796dacb9140  peaq-streamlit/data/3e1a4847-f979-4df0-ab01-f7...
# 32b2aa12-d6c2-40f5-99fd-97dd33cb797d  peaq-streamlit/data/32b2aa12-d6c2-40f5-99fd-97...
# 4f1a7b38-ab65-4806-a832-d180275e06d3  peaq-streamlit/data/4f1a7b38-ab65-4806-a832-d1...
# ec79af03-c27c-4359-8e0d-87d168043423  peaq-streamlit/data/ec79af03-c27c-4359-8e0d-87...
# 52924e12-deb1-476c-8831-687af158811f  peaq-streamlit/data/52924e12-deb1-476c-8831-68...
# d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9  peaq-streamlit/data/d3d526d8-dab7-4e25-a178-dd...
# 8b4eb887-fc8d-4967-bb47-25486c5cd3bf  peaq-streamlit/data/8b4eb887-fc8d-4967-bb47-25...
# 2f525303-a3a9-4ac0-9729-c5a8752ca8ef  peaq-streamlit/data/2f525303-a3a9-4ac0-9729-c5...
# e2997770-5590-473d-8f2d-baa490d1b184  peaq-streamlit/data/e2997770-5590-473d-8f2d-ba...
# 92b1aac7-184f-4830-8b71-d19d522d12a7  peaq-streamlit/data/92b1aac7-184f-4830-8b71-d1...
# ac2ce6ce-7f4c-437b-9e0f-4310ab25334c  peaq-streamlit/data/ac2ce6ce-7f4c-437b-9e0f-43...
# 464139db-cad9-4676-85ea-db7be69135e4  peaq-streamlit/data/464139db-cad9-4676-85ea-db...
# 6ca6a81d-9fa7-48b9-9f64-9a782c3fe020  peaq-streamlit/data/6ca6a81d-9fa7-48b9-9f64-9a...
# 8ca42ddd-cd9f-4117-94f2-9d9cc3735664  peaq-streamlit/data/8ca42ddd-cd9f-4117-94f2-9d...
# 781ed8fb-34ef-4b9a-932a-7b8836870e39  peaq-streamlit/data/781ed8fb-34ef-4b9a-932a-7b...
# 759df116-d5a3-4aec-b9e0-725891cef1d7  peaq-streamlit/data/759df116-d5a3-4aec-b9e0-72...
# ba3da40b-5c52-46bd-8209-8ab0e448bba1  peaq-streamlit/data/ba3da40b-5c52-46bd-8209-8a...
# 549ba9bb-e21e-44c9-ac92-6fa1af2fdfff  peaq-streamlit/data/549ba9bb-e21e-44c9-ac92-6f...

# %%
x = input("Paste assessment_id ")
# Out:
# Paste assessment_id d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9

# %%
fn = f'peaq-streamlit/data/{x.strip()}.json'

# %% [markdown]
# ### Read file from AWS

# %%
#assessment_id = "ba3da40b-5c52-46bd-8209-8ab0e448bba1"
#assessment_id = "759df116-d5a3-4aec-b9e0-725891cef1d7"
#assessment_id = "d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9"
#fn = f"peaq-streamlit/data/{assessment_id}.json"    

df = conn.read(fn, input_format="json", ttl=600)
# Out:
# 2025-04-13 16:41:20.231 No runtime found, using MemoryCacheStorageManager
# 2025-04-13 16:41:20.233 No runtime found, using MemoryCacheStorageManager
# 2025-04-13 16:41:20.234 No runtime found, using MemoryCacheStorageManager
# 2025-04-13 16:41:20.236 No runtime found, using MemoryCacheStorageManager
# 2025-04-13 16:41:20.238 No runtime found, using MemoryCacheStorageManager
# 2025-04-13 16:41:20.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 16:41:20.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 16:41:20.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 16:41:20.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 16:41:20.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
answers = df.pop('answers')
breakdown = df.pop('scores')
df.update(breakdown)

# %%
df_summary = pd.DataFrame.from_dict( {k:[v] for k,v in df.items()}).T
df_summary
# Out:
#                                                                 0
# id                           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# user_id                      dacc397e-1c32-4a5b-b446-827a6c7d4e9f
# timestamp                              2025-04-12T16:46:35.654508
# sex                                                          Male
# overall_score                                                   5
# interpretation  Reassuring result, suggesting that you have a ...
# psychological                                                   5
# physiological                                                  -2
# physical                                                        2

# %%
df_answers = pd.DataFrame.from_dict(answers).T
df_answers['id'] = df['id']
df_answers
# Out:
#                                                          text  \
# 1                                       Please enter your age
# 2                            What is your main exercise type?
# 3           How many hours of exercise do you perform each...
# 4           How do you feel if you have to miss exercise/t...
# 5           Please enter your current height (in metres e....
# 6                    Please enter your current weight (in kg)
# 7           Please enter your lowest weight for your curre...
# 8                  How often do you weight yourself per week?
# 9           As an indication of your hormone levels, how o...
# 10          During the last year how many days off exercis...
# 11          During the last year how many soft tissue inju...
# 12          Of these soft tissue injuries, how many were r...
# 13          If you had bone injuries how many of these wer...
# 14          If you have had any type of fractures, where h...
# 15                                        Are you vegetarian?
# 16                                             Are you vegan?
# 17               Do you exclude carbohydrates from your diet?
# 18                                              Do you smoke?
# 19          How would you rate your levels of freshness ov...
# 20          How would you rate your sleep quality over the...
# 21          How would you rate your digestive system over ...
# 22          How does controlling what you eat affect the w...
# 23          How does controlling what you weigh affect the...
# 24          Have you ever been diagnosed with an eating di...
# BMI                                                       BMI
# Lowest BMI                                         Lowest BMI
#
#                          answer value   unit       category score  \
# 1                            29    29  years           info   NaN
# 2                       Cycling   NaN    NaN           info     0
# 3                         11-15   NaN    NaN           info     0
# 4            Worried or anxious   NaN    NaN           info     0
# 5                          1.83  1.83      m           info   NaN
# 6                            71    71     kg           info   NaN
# 7                            71    71     kg           info   NaN
# 8                  1 to 6 times   NaN    NaN  psychological     0
# 9                  2 or 3 times   NaN    NaN  physiological    -1
# 10                  0 to 6 days   NaN    NaN       physical     0
# 11                         None   NaN    NaN       physical     0
# 12                         None   NaN    NaN       physical     0
# 13                         None   NaN    NaN       physical     0
# 14                           []   NaN    NaN       physical     0
# 15                           No   NaN    NaN  psychological     1
# 16                           No   NaN    NaN  psychological     1
# 17                           No   NaN    NaN  psychological     0
# 18                           No   NaN    NaN  psychological     1
# 19          Frequently fatigued   NaN    NaN  physiological    -1
# 20              Reasonably good   NaN    NaN  physiological     0
# 21             Occasionally bad   NaN    NaN  physiological     0
# 22           Something I manage   NaN    NaN  psychological     0
# 23              Not a big issue   NaN    NaN  psychological     1
# 24                           No   NaN    NaN  psychological     1
# BMI                   21.200991   NaN    NaN       physical     1
# Lowest BMI            21.200991   NaN    NaN       physical     1
#
#                                               id
# 1           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 2           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 3           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 4           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 5           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 6           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 7           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 8           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 9           d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 10          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 11          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 12          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 13          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 14          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 15          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 16          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 17          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 18          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 19          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 20          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 21          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 22          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 23          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# 24          d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# BMI         d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9
# Lowest BMI  d3d526d8-dab7-4e25-a178-ddeeb1cd0ba9

# %% [markdown]
# ### Testing Write to AWS s3

# %%
assessment_id = "ba3da40b-5c52-46bd-8209-8ab0e448bba1"
assessment_id = "759df116-d5a3-4aec-b9e0-725891cef1d7"

# %%
# Open a local assessment
# with open(f"data/{user_id}/{assessment_id}.json",'r') as file:
#     report = json.load(file)
# report

# %%
class DateTimeEncoder(json.JSONEncoder):
    """Custom JSON encoder for datetime objects."""
    def default(self, obj):
        if isinstance(obj, datetime.datetime):
            return obj.isoformat()
        return super().default(obj)

def datetime_decoder(json_dict):
    """Custom JSON decoder for datetime objects."""
    for key, value in json_dict.items():
        if key == "timestamp" and isinstance(value, str):
            try:
                json_dict[key] = datetime.datetime.fromisoformat(value)
            except ValueError:
                pass
    return json_dict

# %%
assessment_data = report

AWS_DIR = Path("peaq-streamlit/data")
#AWS_user_dir = AWS_DIR / user_id
file_path = AWS_DIR / f"{assessment_id}.json"
with conn.open(file_path, 'w') as f:
    json.dump(assessment_data, f, cls=DateTimeEncoder, indent=4)

# %%
# Simple test
with conn.open("peaq-streamlit/text.json",'w') as f:
    f.write(json.dumps(report))

# %%
report
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 report
#
# NameError: name 'report' is not defined

# %%
# !pwd
# Out:
# /Users/Gavin/Gavin/Jupyter/Projects/PEAQ
